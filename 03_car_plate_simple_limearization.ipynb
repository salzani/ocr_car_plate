# %% [markdown]
# # **Limiarização simples**
# -   Transformar uma imagem cinza completamente em preto e branco

# %%
import pytesseract
from pytesseract import Output
import cv2 
import matplotlib.pyplot as plt

# %%
img = cv2.imread('itens/images/placa_carro1.png')
imgGray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

limiar = 25
value, lim_simples = cv2.threshold(imgGray, limiar, 255, cv2.THRESH_BINARY)

plt.imshow(lim_simples)

# %%
limiar = 127
value, lim_simples = cv2.threshold(imgGray, limiar, 255, cv2.THRESH_BINARY)

plt.imshow(lim_simples)

# %%
limiar = 170
value, lim_simples = cv2.threshold(imgGray, limiar, 255, cv2.THRESH_BINARY)

plt.imshow(lim_simples)
